# %%
import os, sys 
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
data_dir = "../../data/ipums/"

# %%
HEADER_END = 9
VARIABLE_LIST = [10, 92]
VAL_LIST = [99, 4167]
def in_range(R, l):
    return l >= R[0] and l <= R[1]

# %%
lines = ['DUMMY']
with open(os.path.join(data_dir, "codebook.txt"), "r") as in_file:
    line_num = 0
    for line in in_file:
        lines.append(line.strip())

var_cols = {} # the columns containing data for a variable
var_descriptions = {} # the column descriptions for a variable 
var_values = {} # a map of the numeric codes to the values they signify for different variables 

line_num = 0

active_var = None
in_box = False
while True:
    line_num += 1
    if line_num == len(lines):
        break
    line = lines[line_num]
        
    if line_num < HEADER_END:
        continue

    if in_range(VARIABLE_LIST, line_num): 
        items = line.strip().replace("\t", " ").split(" ")
        items = [x for x in items if not x == ""]
        var_name, _, cols, length, _ = items
        length = int(length)
        start_col = int(cols.split('-')[0])
        var_cols[var_name] = list(range(start_col, start_col+length))
    
    if  in_range(VAL_LIST, line_num):
        if len(line) == 0:
            in_box = False
            active_var = None
            continue
        
        line = line.replace("\t", " ")
        items = line.split(" ")
        if in_box:
            if len(items) <2:
                continue
            code = items[0]
            value = ' '.join(items[1:])
            #print("Code (%s): %s" % (code, value))
            var_values[active_var][code] = value
        else:
            # starting new var descriptor 
            var_name = items[0]
            var_desc = ' '.join(items[1:])
            var_descriptions[var_name] = var_desc
            print("Adding Variable (%s): %s" % (var_name, var_desc))
            active_var = var_name
            var_values[active_var] = {}
            in_box = True
# Out:
# Adding Variable (YEAR): Census year
# Adding Variable (SAMPLE): IPUMS sample identifier
# Adding Variable (GQ): Group quarters status
# Adding Variable (SEX): Sex
# Adding Variable (AGE): Age
# Adding Variable (MARST): Marital status
# Adding Variable (MARRNO): Times married
# Adding Variable (RACE): Race [general version]
# Adding Variable (RACED): Race [detailed version]
# Adding Variable (HISPAN): Hispanic origin [general version]
# Adding Variable (HISPAND): Hispanic origin [detailed version]
# Adding Variable (BPL): Birthplace [general version]
# Adding Variable (BPLD): Birthplace [detailed version]
# Adding Variable (CITIZEN): Citizenship status
# Adding Variable (YRNATUR): Year naturalized
# Adding Variable (YRIMMIG): Year of immigration
# Adding Variable (YRSUSA1): Years in the United States
# Adding Variable (YRSUSA2): Years in the United States, intervalled
# Adding Variable (HCOVANY): Any health insurance coverage
# Adding Variable (HCOVPRIV): Private health insurance coverage
# Adding Variable (HINSEMP): Health insurance through employer/union
# Adding Variable (HCOVPUB): Public health insurance coverage
# Adding Variable (HINSCAID): Health insurance through Medicaid
# Adding Variable (HINSCARE): Health insurance through Medicare
# Adding Variable (HINSVA): Health insurance through VA
# Adding Variable (HINSIHS): Health insurance through Indian Health Services
# Adding Variable (SCHOOL): School attendance
# Adding Variable (EDUC): Educational attainment [general version]
# Adding Variable (EDUCD): Educational attainment [detailed version]
# Adding Variable (GRADEATT): Grade level attending [general version]
# Adding Variable (GRADEATTD): Grade level attending [detailed version]
# Adding Variable (SCHLTYPE): Public or private school
# Adding Variable (DEGFIELD): Field of degree [general version]
# Adding Variable (DEGFIELDD): Field of degree [detailed version]
# Adding Variable (DEGFIELD2): Field of degree (2) [general version]
# Adding Variable (DEGFIELD2D): Field of degree (2) [detailed version]
# Adding Variable (EMPSTAT): Employment status [general version]
# Adding Variable (EMPSTATD): Employment status [detailed version]
# Adding Variable (LABFORCE): Labor force status
# Adding Variable (CLASSWKR): Class of worker [general version]
# Adding Variable (CLASSWKRD): Class of worker [detailed version]
# Adding Variable (WKSWORK2): Weeks worked last year, intervalled
# Adding Variable (MIGPLAC1): State or country of residence 1 year ago
# Adding Variable (VETDISAB): VA service-connected disability rating
# Adding Variable (DIFFREM): Cognitive difficulty
# Adding Variable (DIFFPHYS): Ambulatory difficulty
# Adding Variable (DIFFMOB): Independent living difficulty
# Adding Variable (DIFFCARE): Self-care difficulty
# Adding Variable (DIFFSENS): Vision or hearing difficulty
# Adding Variable (DIFFEYE): Vision difficulty
# Adding Variable (DIFFHEAR): Hearing difficulty
# Adding Variable (VETSTAT): Veteran status [general version]
# Adding Variable (VETSTATD): Veteran status [detailed version]
# Adding Variable (VET01LTR): Veteran, served 2001 or later
# Adding Variable (VET90X01): Veteran, served 1990-2001
# Adding Variable (VET75X90): Veteran, served May 1975 to July 1990
# Adding Variable (VETVIETN): Veteran, served during Vietnam era
# Adding Variable (VET55X64): Veteran, served 1955 to 1964
# Adding Variable (VETKOREA): Veteran, served during Korean conflict era
# Adding Variable (VET47X50): Veteran, served 1947-1950
# Adding Variable (VETWWII): Veteran, served during WWII era
# Adding Variable (PWSTATE2): Place of work: state
# Adding Variable (TRANWORK): Means of transportation to work
# Adding Variable (OCC): Occupation Name
# Adding Variable (MIGCOUNTY1): State

# %%
data = []
max_count = 100
counter = 0
with open(os.path.join(data_dir, 'usa_00003.dat'), 'r') as in_file:
    for line in in_file:
        counter += 1
        if counter > max_count:
            break
        txt = line.strip()
        row = [x for x in txt]
        data.append(txt)
data = np.array(data)

# %%
IGNORE_VARS = [
    'HHWT',    # Household weight 
    'SERIAL', 
    'CBSERIAL',
    'PERNUM',
    'PERWT',
     'IND', 
    'INDNAICS',
    'FTOTINC',
    'INCWAGE',
    'INCSS',
    'PWCOUNTY',
    'SAMPLE',
    'GQ'
]
AS_IS_VARS = [
    'BIRTHYR', # Year in which respondent was born
    'YRMARR', # Year in which respondent was married
    'INCTOT', # each respondent's total pre-tax personal income or losses from all sources for the previous year  
    'INCWELFR', # income from welfare programs
    'INCINVST', # how much pre-tax money the respondent received or lost during the previous year in the form of income from an estate or trust
    'POVERTY', # 3-digit numeric code expressing each family's total income for the previous year as a percentage of the poverty thresholds 
    'YRSUSA1', # 2-digit numeric code reporting how long a person who was born in a foreign country or U.S. outlying area had been living in the United States
    'YEAR'
]

# %%
data_dict = defaultdict(list)
for record in data:
    for var, indices in var_cols.items():
        if var in IGNORE_VARS:
            continue
        code = record[indices[0]-1:indices[-1]]
        print(var, code)
        if var in AS_IS_VARS:
            value = code
        else:
            value = var_values[var][code]
        data_dict[var].append(value)
# Out:
# YEAR 2017
# SEX 1
# AGE 073
# MARST 3
# BIRTHYR 1944
# MARRNO 1
# YRMARR 1979
# RACE 2
# RACED 200
# HISPAN 0
# HISPAND 000
# BPL 001
# BPLD 00100
# CITIZEN 0
# YRNATUR 9999
# YRIMMIG 0000
# YRSUSA1 00
# YRSUSA2 0
# HCOVANY 2
# HCOVPRIV 1
# HINSEMP 1
# HCOVPUB 2
# HINSCAID 1
# HINSCARE 2
# HINSVA 1
# HINSIHS 1
# SCHOOL 1
# EDUC 02
# EDUCD 025
# GRADEATT 0
# GRADEATTD 00
# SCHLTYPE 1
# DEGFIELD 00
# DEGFIELDD 0000
# DEGFIELD2 00
# DEGFIELD2D 0000
# EMPSTAT 3
# EMPSTATD 30
# LABFORCE 1
# OCC 0000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-a176c838b809> in <module>()
#       9             value = code
#      10         else:
# ---> 11             value = var_values[var][code]
#      12         data_dict[var].append(value)
#
# KeyError: '0000'

# %%
data = pd.DataFrame.from_dict(data_dict)

# %%
pd.set_option('display.max_columns', None)  
data.head()
# Out:
#    YEAR    SAMPLE    SERIAL       CBSERIAL        HHWT  \
# 0  2017  2017 ACS  00000001  2017000000016  0000020600
# 1  2017  2017 ACS  00000002  2017000000031  0000004500
# 2  2017  2017 ACS  00000003  2017000000061  0000013600
# 3  2017  2017 ACS  00000003  2017000000061  0000013600
# 4  2017  2017 ACS  00000003  2017000000061  0000013600
#
#                                  GQ PERNUM       PERWT     SEX AGE  \
# 0  Households under 1970 definition  0001   0000020600  Male    73
# 1  Households under 1970 definition  0001   0000004500  Female  31
# 2  Households under 1970 definition  0001   0000013600  Male    41
# 3  Households under 1970 definition  0002   0000012100  Female  48
# 4  Households under 1970 definition  0003   0000011100  Male    16
#
#                      MARST BIRTHYR                   MARRNO YRMARR  \
# 0  Separated                1944    Married once             1979
# 1  Never married/single     1986    Not Applicable           0000
# 2  Married, spouse present  1976    Married twice (or more)  2000
# 3  Married, spouse present  1969    Married twice (or more)  2000
# 4  Never married/single     2001    Not Applicable           0000
#
#                            RACE                         RACED        HISPAN  \
# 0  Black/African American/Negro  Black/African American/Negro  Not Hispanic
# 1  White                         White                         Not Hispanic
# 2  White                         White                         Mexican
# 3  White                         White                         Not Hispanic
# 4  White                         White                         Mexican
#
#         HISPAND       BPL      BPLD CITIZEN YRNATUR YRIMMIG YRSUSA1 YRSUSA2  \
# 0  Not Hispanic  Alabama   Alabama   N/A     N/A     N/A     00      N/A
# 1  Not Hispanic  Georgia   Georgia   N/A     N/A     N/A     00      N/A
# 2  Mexican       Georgia   Georgia   N/A     N/A     N/A     00      N/A
# 3  Not Hispanic  Illinois  Illinois  N/A     N/A     N/A     00      N/A
# 4  Mexican       Alabama   Alabama   N/A     N/A     N/A     00      N/A
#
#                           HCOVANY                                   HCOVPRIV  \
# 0  With health insurance coverage  Without private health insurance coverage
# 1  With health insurance coverage  With private health insurance coverage
# 2  With health insurance coverage  With private health insurance coverage
# 3  With health insurance coverage  With private health insurance coverage
# 4  With health insurance coverage  With private health insurance coverage
#
#                                 HINSEMP  \
# 0  No insurance through employer/union
# 1  Has insurance through employer/union
# 2  Has insurance through employer/union
# 3  Has insurance through employer/union
# 4  Has insurance through employer/union
#
#                                     HCOVPUB                        HINSCAID  \
# 0  With public health insurance coverage     No insurance through Medicaid
# 1  Without public health insurance coverage  No insurance through Medicaid
# 2  With public health insurance coverage     Has insurance through Medicaid
# 3  With public health insurance coverage     Has insurance through Medicaid
# 4  With public health insurance coverage     Has insurance through Medicaid
#
#   HINSCARE                   HINSVA  \
# 0  Yes      No insurance through VA
# 1  No       No insurance through VA
# 2  No       No insurance through VA
# 3  No       No insurance through VA
# 4  No       No insurance through VA
#
#                                       HINSIHS             SCHOOL  \
# 0  No insurance through Indian Health Service  No, not in school
# 1  No insurance through Indian Health Service  No, not in school
# 2  No insurance through Indian Health Service  No, not in school
# 3  No insurance through Indian Health Service  No, not in school
# 4  No insurance through Indian Health Service  Yes, in school
#
#                   EDUC                          EDUCD             GRADEATT  \
# 0  Grade 5, 6, 7, or 8  Grade 7                        N/A
# 1  4 years of college   Bachelor's degree              N/A
# 2  Grade 12             GED or alternative credential  N/A
# 3  Grade 12             Regular high school diploma    N/A
# 4  Grade 10             Grade 10                       Grade 9 to grade 12
#
#   GRADEATTD       SCHLTYPE                                  DEGFIELD  \
# 0  N/A       Not enrolled   N/A
# 1  N/A       Not enrolled   Medical and Health Sciences and Services
# 2  N/A       Not enrolled   N/A
# 3  N/A       Not enrolled   N/A
# 4  Grade 10  Public school  N/A
#
#                              DEGFIELDD DEGFIELD2 DEGFIELD2D  \
# 0  N/A                                  N/A       N/A
# 1  General Medical and Health Services  N/A       N/A
# 2  N/A                                  N/A       N/A
# 3  N/A                                  N/A       N/A
# 4  N/A                                  N/A       N/A
#
#               EMPSTAT            EMPSTATD                    LABFORCE   OCC  \
# 0  Not in labor force  Not in Labor Force  No, not in the labor force  0000
# 1  Employed            At work             Yes, in the labor force     0350
# 2  Employed            At work             Yes, in the labor force     6260
# 3  Not in labor force  Not in Labor Force  No, not in the labor force  0000
# 4  Not in labor force  Not in Labor Force  No, not in the labor force  0000
#
#     IND         CLASSWKR             CLASSWKRD  INDNAICS     WKSWORK2  \
# 0  0000  N/A              N/A                          0  N/A
# 1  8090  Works for wages  Wage/salary, private  6214      50-52 weeks
# 2  0770  Works for wages  Wage/salary, private  23        50-52 weeks
# 3  0000  N/A              N/A                          0  N/A
# 4  0000  N/A              N/A                          0  N/A
#
#     INCTOT  FTOTINC INCWAGE  INCSS INCWELFR INCINVST INCRETIR POVERTY  \
# 0  0010000  0010000  000000  10000  00000    000000   000000   085
# 1  0038500  0038500  038500  00000  00000    000000   000000   302
# 2  0082000  0090700  072000  00000  00000    010000   000000   467
# 3  0008700  0090700  000000  00000  00000    000000   000000   467
# 4  0000000  0090700  000000  00000  00000    000000   000000   467
#
#   MIGPLAC1 MIGCOUNTY1 VETDISAB                   DIFFREM  \
# 0  N/A      000        N/A      Has cognitive difficulty
# 1  N/A      000        N/A      No cognitive difficulty
# 2  N/A      000        N/A      No cognitive difficulty
# 3  N/A      000        N/A      No cognitive difficulty
# 4  N/A      000        N/A      No cognitive difficulty
#
#                     DIFFPHYS                           DIFFMOB DIFFCARE  \
# 0  Has ambulatory difficulty  No independent living difficulty  No
# 1  No ambulatory difficulty   No independent living difficulty  No
# 2  No ambulatory difficulty   No independent living difficulty  No
# 3  No ambulatory difficulty   No independent living difficulty  No
# 4  No ambulatory difficulty   No independent living difficulty  No
#
#                           DIFFSENS DIFFEYE DIFFHEAR        VETSTAT  \
# 0  No vision or hearing difficulty  No      No       Not a veteran
# 1  No vision or hearing difficulty  No      No       Not a veteran
# 2  No vision or hearing difficulty  No      No       Not a veteran
# 3  No vision or hearing difficulty  No      No       Not a veteran
# 4  No vision or hearing difficulty  No      No       N/A
#
#               VETSTATD VET01LTR VET90X01   VET75X90                 VETVIETN  \
# 0  No military service  N/A      N/A      N/A or No  N/A (all years) and No)
# 1  No military service  N/A      N/A      N/A or No  N/A (all years) and No)
# 2  No military service  N/A      N/A      N/A or No  N/A (all years) and No)
# 3  No military service  N/A      N/A      N/A or No  N/A (all years) and No)
# 4  N/A                  N/A      N/A      N/A or No  N/A (all years) and No)
#
#     VET55X64   VETKOREA VET47X50                         VETWWII PWSTATE2  \
# 0  N/A or No  N/A or No  N/A      N/A; N/A or No (1980, 1990 US)  N/A
# 1  N/A or No  N/A or No  N/A      N/A; N/A or No (1980, 1990 US)  Alabama
# 2  N/A or No  N/A or No  N/A      N/A; N/A or No (1980, 1990 US)  Georgia
# 3  N/A or No  N/A or No  N/A      N/A; N/A or No (1980, 1990 US)  N/A
# 4  N/A or No  N/A or No  N/A      N/A; N/A or No (1980, 1990 US)  N/A
#
#   PWCOUNTY             TRANWORK
# 0  000      N/A
# 1  117      Auto, truck, or van
# 2  000      Auto, truck, or van
# 3  000      N/A
# 4  000      N/A

# %%
var_values['OCC']['0000']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-d99717bc115b> in <module>()
# ----> 1 var_values['OCC']['0000']
#
# KeyError: '0000'
